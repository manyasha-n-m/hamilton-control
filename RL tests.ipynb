# %%
import numpy as np
from time import time
from optimize import RLnetwork
from models import Model1

# %%
init_state = np.array([6, 4, 0, 0])

# %% [markdown]
# ## standard parameters

# %%
m2 = Model1(init_state)
net = RLnetwork(m2.f, m2.g, 8, N=10)
u = net.u(m2.state)

for i in range(990):
    m2.update(u)
    t = time()
    u = net.optimize(m2.state)
    print(time()-t) if i%100==0 else _

print('current state:', m2.state)
print('V(x0) =', net.V(init_state))

m2.plot_evolution
# Out:
# 0.017990827560424805
# 0.010002613067626953
# 0.0049817562103271484
# 0.010982275009155273
# 0.008003950119018555
# 0.011965513229370117
# 0.004999399185180664
# 0.012016773223876953
# 0.00499415397644043
# 0.010023832321166992
# current state: [   8.03168502    1.96831498 1652.32929876 1501.90909654]
# V(x0) = 62.518319320411074
# <module 'matplotlib.pyplot' from 'C:\\Users\\manyasha_n_m\\Desktop\\FI81\\4\\diploma\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ### let's test this network on different initial states and goals

# %%
m3 = Model1(init_state)
for i in range(990):
    u = net.u(m3.state)
    m3.update(u)

print('current state:', m3.state)
print('V(x0) =', net.V(init_state))

m3.plot_evolution
# Out:
# current state: [   8.05591192    1.94408808 1616.89631789 1506.28746789]
# V(x0) = 62.336677430725835
# <module 'matplotlib.pyplot' from 'C:\\Users\\manyasha_n_m\\Desktop\\FI81\\4\\diploma\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
m3 = Model1(np.array([7, 3, 0, 0]))
for i in range(990):
    u = net.u(m3.state)
    m3.update(u)

print('current state:', m3.state)
print('V(x0) =', net.V(init_state))

m3.plot_evolution
# Out:
# current state: [   8.05591191    1.94408809 1620.75759614 1505.3961638 ]
# V(x0) = 62.336677430725835
# <module 'matplotlib.pyplot' from 'C:\\Users\\manyasha_n_m\\Desktop\\FI81\\4\\diploma\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
m3 = Model1(np.array([6, 3, 0, 0]))
for i in range(990):
    u = net.u(m3.state)
    m3.update(u)

print('current state:', m3.state)
print('V(x0) =', net.V(init_state))

m3.plot_evolution
# Out:
# current state: [8.05032071e+00 9.49679295e-01 1.61339578e+03 1.49124632e+03]
# V(x0) = 62.336677430725835
# <module 'matplotlib.pyplot' from 'C:\\Users\\manyasha_n_m\\Desktop\\FI81\\4\\diploma\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
m3 = Model1(np.array([10, 7, 0, 0]))
for i in range(990):
    u = net.u(m3.state)
    m3.update(u)

print('current state:', m3.state)
print('V(x0) =', net.V(init_state))

m3.plot_evolution
# Out:
# current state: [   8.09505114    8.90494886 1656.28540254 1868.91508231]
# V(x0) = 62.336677430725835
# <module 'matplotlib.pyplot' from 'C:\\Users\\manyasha_n_m\\Desktop\\FI81\\4\\diploma\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
net.I_ = [10, -10, 0, 0]

# %%
m3 = Model1(np.array([12, 7, 0, 0]))
for i in range(990):
    u = net.u(m3.state)
    m3.update(u)

print('current state:', m3.state)
print('V(x0) =', net.V(init_state))

m3.plot_evolution
# Out:
# current state: [  10.03033634    8.96966366 2010.93631435 1873.23285756]
# V(x0) = 67.04878186329597
# <module 'matplotlib.pyplot' from 'C:\\Users\\manyasha_n_m\\Desktop\\FI81\\4\\diploma\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
net.I_ = [50, -50, 0, 0]

# %%
m3 = Model1(np.array([40, 60, 0, 0]))
for i in range(990):
    u = net.u(m3.state)
    m3.update(u)

print('current state:', m3.state)
print('V(x0) =', net.V(init_state))

m3.plot_evolution
# Out:
# current state: [   43.92654956    56.07345044 20053.56187666 17076.72485523]
# V(x0) = 788.590219804513
# <module 'matplotlib.pyplot' from 'C:\\Users\\manyasha_n_m\\Desktop\\FI81\\4\\diploma\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ## N=20

# %%
m2 = Model1(np.array(init_state))
net = RLnetwork(m2.f, m2.g, 8, N=20)
u = net.u(m2.state)

for i in range(990):
    m2.update(u)
    t = time()
    u = net.optimize(m2.state)
    print(time()-t) if i%100==0 else _

print('\ncurrent state:', m2.state)
print('V(x0) =', net.V(init_state))
m2.plot_evolution
# Out:
# 0.013522148132324219
# 0.023002147674560547
# 0.00999903678894043
# 0.008987665176391602
# 0.02001667022705078
# 0.020981550216674805
# 0.013995885848999023
# 0.009980440139770508
# 0.010982990264892578
# 0.020978689193725586
#
# current state: [   8.09387738    1.90612262 1656.50510194 1501.48856927]
# V(x0) = 62.86070481546796
# <module 'matplotlib.pyplot' from 'C:\\Users\\manyasha_n_m\\Desktop\\FI81\\4\\diploma\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ## na1=1

# %%
m2 = Model1(init_state)
net = RLnetwork(m2.f, m2.g, 8, N=10, na1=1)
u = net.u(m2.state)

for i in range(990):
    m2.update(u)
    t = time()
    u = net.optimize(m2.state)
    print(time()-t) if i%100==0 else _

print('current state:', m2.state)
print('V(x0) =', net.V(init_state))

m2.plot_evolution
# Out:
# 0.012816190719604492
# 0.010999679565429688
# 0.010999917984008789
# 0.004990100860595703
# 0.005998373031616211
# 0.00600433349609375
# 0.009001016616821289
# 0.014974355697631836
# 0.00598597526550293
# 0.004996061325073242
# current state: [   7.99544505    2.00455495 1705.4895682  1497.62121689]
# V(x0) = 62.2145432405885
# <module 'matplotlib.pyplot' from 'C:\\Users\\manyasha_n_m\\Desktop\\FI81\\4\\diploma\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# ## nc1=10

# %%
m2 = Model1(init_state)
net = RLnetwork(m2.f, m2.g, 8, N=10, nc1=10)
u = net.u(m2.state)

for i in range(990):
    m2.update(u)
    t = time()
    u = net.optimize(m2.state)
    print(time()-t) if i%100==0 else _

print('current state:', m2.state)
print('V(x0) =', net.V(init_state))

m2.plot_evolution
# Out:
# 0.012990236282348633
# 0.0050122737884521484
# 0.007995843887329102
# 0.010003805160522461
# 0.0049817562103271484
# 0.0069963932037353516
# 0.006000041961669922
# 0.004991769790649414
# 0.006003141403198242
# 0.00599980354309082
# current state: [   8.03318108    1.96681892 1614.63479499 1506.69426009]
# V(x0) = 62.09109688742652
# <module 'matplotlib.pyplot' from 'C:\\Users\\manyasha_n_m\\Desktop\\FI81\\4\\diploma\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
m3 = Model1(init_state)
for i in range(990):
    u = net.u(m3.state)
    m3.update(u)

print('current state:', m3.state)
print('V(x0) =', net.V(init_state))

m3.plot_evolution
# Out:
# current state: [   8.02206793    1.97793207 1611.96792823 1506.90308931]
# V(x0) = 62.09109688742652
# <module 'matplotlib.pyplot' from 'C:\\Users\\manyasha_n_m\\Desktop\\FI81\\4\\diploma\\env\\lib\\site-packages\\matplotlib\\pyplot.py'>
